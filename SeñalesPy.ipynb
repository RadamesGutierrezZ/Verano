# %%
from obspy import read

# %%
stE = read ("ST03L173.SV.EHE*.mseed")
stN = read ("ST03L173.SV.EHN*.mseed")
stZ = read ("ST03L173.SV.EHZ*.mseed")

# %%
stZ
# Out:
# 3 Trace(s) in Stream:
# SV.ST03L..EHZ | 2016-04-26T11:00:00.000000Z - 2016-04-26T11:59:59.990000Z | 100.0 Hz, 360000 samples
# SV.ST03L..EHZ | 2016-04-26T12:00:00.000000Z - 2016-04-26T12:59:59.990000Z | 100.0 Hz, 360000 samples
# SV.ST03L..EHZ | 2016-04-26T13:00:00.000000Z - 2016-04-26T13:59:59.990000Z | 100.0 Hz, 360000 samples

# %%
stZ.plot()
# Out:
# /home/taller/anaconda2/lib/python2.7/site-packages/matplotlib/cbook.py:136: MatplotlibDeprecationWarning: The axisbg attribute was deprecated in version 2.0. Use facecolor instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
trZ = stZ[1].copy()

# %%
t1 = trZ.stats.starttime

# %%
trZ.trim(t1+(4*60),t1+(7*60))
# Out:
# SV.ST03L..EHZ | 2016-04-26T12:04:00.000000Z - 2016-04-26T12:07:00.000000Z | 100.0 Hz, 18001 samples

# %%
trE = stE[1].copy()

# %%
t2 = trE.stats.starttime

# %%
trE.trim(t2+(4*60),t2+(7*60))
# Out:
# SV.ST03L..EHE | 2016-04-26T12:04:00.000000Z - 2016-04-26T12:07:00.000000Z | 100.0 Hz, 18001 samples

# %%
trN = stN[1].copy()

# %%
t3 = trN.stats.starttime

# %%
trN.trim(t3+(4*60),t3+(7*60))
# Out:
# SV.ST03L..EHN | 2016-04-26T12:04:00.000000Z - 2016-04-26T12:07:00.000000Z | 100.0 Hz, 18001 samples

# %%
trZ.write("Sismo1Z.SAC",format="SAC")

# %%
trE.write("Sismo1E.SAC",format="SAC")

# %%
trN.write("Sismo1N.SAC",format="SAC")

# %%
ls
# Out:
# Juliaexpress.ipynb                      ST03L173.SV.EHE..20160426_130000.mseed
# Proyecto.ipynb                          ST03L173.SV.EHN..20160426_110000.mseed
# Py señales.ipynb                        ST03L173.SV.EHN..20160426_120000.mseed
# README.md                               ST03L173.SV.EHN..20160426_130000.mseed
# ResumenJuliacon2017.ipynb               ST03L173.SV.EHZ..20160426_110000.mseed
# Sismo1E.SAC                             ST03L173.SV.EHZ..20160426_120000.mseed
# Sismo1N.SAC                             ST03L173.SV.EHZ..20160426_130000.mseed
# Sismo1Z                                 SV.ST03L..EHE.SAC
# Sismo1Z.sac                             SV.ST03L..EHN.SAC
# Sismo1Z.SAC                             SV.ST03L..EHZ.SAC
# ST03L173.SV.EHE..20160426_110000.mseed  Untitled.ipynb
# ST03L173.SV.EHE..20160426_120000.mseed  VeranoIntro.ipynb

# %%
ls
# Out:
# Juliaexpress.ipynb                      ST03L173.SV.EHN..20160426_110000.mseed
# Proyecto.ipynb                          ST03L173.SV.EHN..20160426_120000.mseed
# Py señales.ipynb                        ST03L173.SV.EHN..20160426_130000.mseed
# README.md                               ST03L173.SV.EHZ..20160426_110000.mseed
# ResumenJuliacon2017.ipynb               ST03L173.SV.EHZ..20160426_120000.mseed
# Sismo1E.SAC                             ST03L173.SV.EHZ..20160426_130000.mseed
# Sismo1N.SAC                             SV.ST03L..EHE.SAC
# Sismo1Z.SAC                             SV.ST03L..EHN.SAC
# ST03L173.SV.EHE..20160426_110000.mseed  SV.ST03L..EHZ.SAC
# ST03L173.SV.EHE..20160426_120000.mseed  Untitled.ipynb
# ST03L173.SV.EHE..20160426_130000.mseed  VeranoIntro.ipynb

# %%
trZ
# Out:
# SV.ST03L..EHZ | 2016-04-26T12:04:00.000000Z - 2016-04-26T12:07:00.000000Z | 100.0 Hz, 18001 samples

# %%
trZ2 = stZ[2].copy()

# %%
trZ2.plot()

# %%
t21 = trZ2.stats.starttime

# %%
trZ2.trim(t21+(30*60),t21+(50*60))
# Out:
# SV.ST03L..EHZ | 2016-04-26T13:30:00.000000Z - 2016-04-26T13:50:00.000000Z | 100.0 Hz, 120001 samples

# %%
trZ2.plot()

# %%
trZ2.trim(t21+(38*60),t21+(48*60))
# Out:
# SV.ST03L..EHZ | 2016-04-26T13:38:00.000000Z - 2016-04-26T13:48:00.000000Z | 100.0 Hz, 60001 samples

# %%
trZ2.plot()

# %%
trZ2.trim(t21+(40*60),t21+(42*60))
# Out:
# SV.ST03L..EHZ | 2016-04-26T13:40:00.000000Z - 2016-04-26T13:42:00.000000Z | 100.0 Hz, 12001 samples

# %%
trZ2.plot()

# %%
trE2 = stE[2].copy()

# %%
t22 = trE2.stats.starttime

# %%
trE2.trim(t22+(40*60),t22+(42*60))
# Out:
# SV.ST03L..EHE | 2016-04-26T13:40:00.000000Z - 2016-04-26T13:42:00.000000Z | 100.0 Hz, 12001 samples

# %%
trE2.plot()

# %%
trN2 = stN[2].copy()

# %%
t23 = trN2.stats.starttime

# %%
trN2.trim(t23+(40*60),t23+(42*60))
# Out:
# SV.ST03L..EHN | 2016-04-26T13:40:00.000000Z - 2016-04-26T13:42:00.000000Z | 100.0 Hz, 12001 samples

# %%
trN2.plot()

# %%
trZ2.write("Sismo2Z.SAC",format="SAC")

# %%
trE2.write("Sismo2E.SAC",format="SAC")

# %%
trN2.write("Sismo2N.SAC",format="SAC")

# %%
ls
# Out:
# Juliaexpress.ipynb                      ST03L173.SV.EHE..20160426_130000.mseed
# Proyecto.ipynb                          ST03L173.SV.EHN..20160426_110000.mseed
# Py señales.ipynb                        ST03L173.SV.EHN..20160426_120000.mseed
# README.md                               ST03L173.SV.EHN..20160426_130000.mseed
# ResumenJuliacon2017.ipynb               ST03L173.SV.EHZ..20160426_110000.mseed
# Sismo1E.SAC                             ST03L173.SV.EHZ..20160426_120000.mseed
# Sismo1N.SAC                             ST03L173.SV.EHZ..20160426_130000.mseed
# Sismo1Z.SAC                             SV.ST03L..EHE.SAC
# Sismo2E.SAC                             SV.ST03L..EHN.SAC
# Sismo2N.SAC                             SV.ST03L..EHZ.SAC
# Sismo2Z.SAC                             Untitled.ipynb
# ST03L173.SV.EHE..20160426_110000.mseed  VeranoIntro.ipynb
# ST03L173.SV.EHE..20160426_120000.mseed
